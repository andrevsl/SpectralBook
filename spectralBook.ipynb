# %% [markdown]
# # Welcome to your Applied Electromgnetism Book
#
# [spectralbook.netlify.app](https://spectralbook.netlify.app/intro.html)
#
# [Colab_Link](https://drive.google.com/file/d/12y1tnL-uvKFW1sLm86MujLTRaO2aWDPZ/view?usp=drive_link)
# [Jupyter_Book_Version](https://drive.google.com/drive/folders/1hQHyDhQYv9Mug6ddjhGET2CvqbNJKyyB?usp=drive_link)
# [Book_func](https://drive.google.com/drive/folders/18vcEtTFuxsFom8V9ZgnRfmgFxi18YsHQ?usp=sharing)
# [Book_Folder](https://drive.google.com/drive/folders/1fik2am3yesKJijJYTo5h5hygKeXPQmTZ?usp=drive_link)
#
# <style>
# r { color: Red }
# o { color: Orange }
# g { color: Green }
# o { color: Orange }
# </style>
#
#
# ## <r> **Spectral Transformations**
# ### [<g> **Spectral Transformation**](ChapterSpectral.ipynb)
#
# Google Colab: https://drive.google.com/file/d/13Pjf31NMQFpUVPqsjrrzElLlv7HdKxH9/view?usp=drive_link
#
# - General Formulation
# - Sine/Cosine Transforms
# - Circular Transforrms
# - Fourier Transform
# - Fourier-Bessel Transform
#
# ### <g> **Window Signals**
#
# - Rectangular Pulse Signal
# - Raised Cosine Signal
# - Window Effect
#
# ### <g> **Narrow Band Signals**
#
# - Sinusoidal Signal half cycle,one cycle
# - Sinusoidal Signal Infinity cycles
# - Phase analysis
#
# ### <g> **Wideband Signals**
#
# - Gaussian Signal
# - 1st and 2nd order derivatives of Gaussian Signal
#
# ### <g> **Space-time-Angle Signals**
#
# - Space-time-Angle Fields/Voltages
#
# ## [<r> **Electromagnetic Spectral Methods**](ChapterEMMethod.ipynb)
# Google Colab: https://drive.google.com/file/d/1NoK-qxDeQQHBQMwHkCy_m95f2T_u8bRL/view?usp=sharing
#
# Exercises Colab: https://drive.google.com/file/d/1NpGi4MVJNy1QFUepqLDjuzFzkhfvMUPW/view?usp=sharing
# - Plane Wave Spectrum
# - Green Functions
# - Sturm Liouville Problems
# - Spectral Solution of Green Dyadic's equations
# - Method of Momentss
# - FDTD
#
# ## <r> **Microwave Circuits**
# Google Colab: https://drive.google.com/file/d/186cQ-leDyDpDGfLVsOqFmRGBX7PyZWrB/view?usp=sharing
#
# - Foward/backward Waves
# - Transmision Line
#     - Parralell Wire
#     - Microstrip
#
# - Waveguides
#     - Fiber
#     - SIW
#
#
# ## <r> **Application to Microwave Circuits**
# Google Colab: https://drive.google.com/file/d/186cQ-leDyDpDGfLVsOqFmRGBX7PyZWrB/view?usp=sharing
#
# - Shorted/Open Transmission Lines
# - Resistive Transmission Lines
# - Inductive Transmission Lines
# - Capacitive Transmission Lines
#
# ## <r> **Application to Microwave Devices I: Filters and Phase Shifters**
#
# - Passband RLC shunt/series  (Narrow/Wideband response)
# - Band Stop (Narrow/Wideband response)
# - High Pass  (Narrow/Wideband response)
# - Low Pass  (Narrow/Wideband response)
# - Frequency Responce and Foster Theorem
#
# ## <r> **Application to Microwave Devices II: Amplifiers and Oscilators**
#
#
# ## <r> **Application to PCB Integrated Circuits I: Filters and Phase Shifters**
#
# - Design with CST/ADS/Altium/Kikad
#
# ## <r> **Application to PCB Integrated Circuits II: Ampllifiers and Oscillators**
#
# - Design with CST/ADS/Altium/Kikad
#
# ## <r> **Application to Digital Filters**
#
# - Digital
# - Analog/Digital Filters
#
# ## <r> **Application to Power Systems**
#
# - T/PI Circuits high power
# - Temporal Symmetric/Asymmetric Components Short Circuits
# - Partial discharges in Hydrogenerators/Transformers
# - Lightning Signals
#
# ## <r> **Application to Antennas**
# Colab: https://drive.google.com/file/d/1NkFJRtvAhLxQXU83n7l5Q3QMF3Y872lA/view?usp=sharing
# - Antenna Dipole
# - Antenna Loop
# - Analytical Expression for Equivalent Circuits
# - Radiation Conditions and Angle/Phase-frequency Bandwidth
#
# ## <r> **Application to Phased Arrays and RIS**
# colab: https://drive.google.com/file/d/1G6YjHTOyPRJN96AuBGXPXflwjRYUNFtg/view?usp=sharing
# - Far-Field Approximations by spectral-angular transforms
# - Near-Field Approximations by spectral-angular transforms
#
#
# ## <r> **Application to Lens and Metasurfaces**
# Colab: https://drive.google.com/file/d/1NnvwSLS7opD5P9Q81igoVQPa7w-lBF7P/view?usp=sharing
#
# - Arrays weights
# - Plane Wave Specturm
# - Fresnel Zone Plates
# - Transformation Optics
#
#
#
# ## <r> **Application to RF Propagation**
#
# - Propagations Models using Spectral techniques
# - Others things that I don't know
#
#
# ## <r> **Application to Wireless Channels and Space-Time Access**
#
# - Radiation and Space-Time Degrees of Freedom
# - Channels Parameters
# - Other things that I don't know
#
# ## <r> **Application to Digital/Control Systems**
#
# - Data Processing Architectures
# - Analog Computers
#
# ## <r> **Application to Optical Systems and Photonic I**
# - Metamaterials RH/LH Materials
# - CRLH - Phase/Group Velocity -  Dispersion
#
# ## <r> **Application to Optical Systems and Photonic II**
#
# ## <r> **Application to Optical Systems and Photonic III**
# - Time-Space Group Symmetry
